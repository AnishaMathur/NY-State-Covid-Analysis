# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/raw_datasets/owid-covid-data.csv',parse_dates=['date'])

# %% [markdown]
# In our data frame df_US we have filtered continent value as North America and iso_code = USA

# %%
df_US = df.loc[(df['continent'] == 'North America') & (df['iso_code']== 'USA')]

# %%
df_US.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed   total_deaths  \
# count  7.630000e+02  7.620000e+02          757.000000     725.000000
# mean   2.455143e+07  1.032135e+05       103604.717501  438787.348966
# std    2.083694e+07  1.486003e+05       135728.050470  273443.381632
# min    1.000000e+00  0.000000e+00            0.000000       1.000000
# 25%    4.511990e+06  2.843500e+04        29101.571000  181457.000000
# 50%    2.708406e+07  5.661200e+04        64224.571000  509411.000000
# 75%    3.692580e+07  1.249408e+05       127016.143000  632841.000000
# max    7.864865e+07  1.368120e+06       802474.857000  939064.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count   725.000000           725.000000               763.000000
# mean   1295.260690          1289.616339             73746.821370
# std     986.333433           795.638853             62589.342603
# min       0.000000             0.143000                 0.003000
# 25%     526.000000           720.000000             13552.974500
# 50%    1012.000000          1063.571000             81354.277000
# 75%    1889.000000          1835.143000            110916.577500
# max    4442.000000          3403.000000            236242.385000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count             762.000000                      757.000000
# mean              310.029386                      311.204646
# std               446.360962                      407.695738
# min                 0.000000                        0.000000
# 25%                85.412250                       87.414000
# 50%               170.049500                      192.916000
# 75%               375.293250                      381.527000
# max              4109.517000                     2410.449000
#
#        total_deaths_per_million  ...  female_smokers  male_smokers  \
# count                725.000000  ...    7.630000e+02  7.630000e+02
# mean                1318.015847  ...    1.910000e+01  2.460000e+01
# std                  821.360784  ...    2.417430e-13  3.910549e-14
# min                    0.003000  ...    1.910000e+01  2.460000e+01
# 25%                  545.055000  ...    1.910000e+01  2.460000e+01
# 50%                 1530.153000  ...    1.910000e+01  2.460000e+01
# 75%                 1900.908000  ...    1.910000e+01  2.460000e+01
# max                 2820.731000  ...    1.910000e+01  2.460000e+01
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count                     0.0                7.630000e+02     7.630000e+02
# mean                      NaN                2.770000e+00     7.886000e+01
# std                       NaN                1.510894e-14     4.834860e-13
# min                       NaN                2.770000e+00     7.886000e+01
# 25%                       NaN                2.770000e+00     7.886000e+01
# 50%                       NaN                2.770000e+00     7.886000e+01
# 75%                       NaN                2.770000e+00     7.886000e+01
# max                       NaN                2.770000e+00     7.886000e+01
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count             7.630000e+02                            103.000000
# mean              9.260000e-01                         449081.835922
# std               5.776947e-15                         299733.534380
# min               9.260000e-01                         -13678.000000
# 25%               9.260000e-01                         176077.700000
# 50%               9.260000e-01                         519110.800000
# 75%               9.260000e-01                         654613.900000
# max               9.260000e-01                         950492.300000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                   103.000000        103.000000
# mean                     12.061553         16.559417
# std                       5.671857         11.903115
# min                      -3.590000         -2.650000
# 25%                      10.520000          6.830000
# 50%                      14.410000         14.340000
# 75%                      15.930000         23.480000
# max                      17.480000         45.920000
#
#        excess_mortality_cumulative_per_million
# count                               103.000000
# mean                               1348.938126
# std                                 900.330318
# min                                 -41.085553
# 25%                                 528.896748
# 50%                                1559.288961
# 75%                                1966.308981
# max                                2855.059366
#
# [8 rows x 62 columns]

# %% [markdown]
# Let us start exploring our data.
#
# **1. What is the trend of Covid Cases so far in US**

# %%
df_US = df_US.fillna(0)

# %%
df_covid_cases = df_US.filter(['new_cases','date'], axis=1)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_covid_cases['date'], df_covid_cases['new_cases'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("NEW COVID CASES", fontsize=14)
plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('TREND OF DAILY NEW COVID CASES IN US', fontsize=16)
# Out:
# Text(0.5, 0.98, 'TREND OF DAILY NEW COVID CASES IN US')

# %% [markdown]
# **2. What is the trend of Total Cases (Cummulative)**

# %%
df_total_cases = df_US.filter(['total_cases','date'], axis=1)
plt.figure(figsize=(20,4))
plt.plot(df_total_cases['date'], df_total_cases['total_cases'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("TOTAL COVID CASES", fontsize=14)
plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('TREND OF CUMMULATIVE COVID CASES IN US', fontsize=16)
# Out:
# Text(0.5, 0.98, 'TREND OF CUMMULATIVE COVID CASES IN US')

# %% [markdown]
# **3. What is the trend of Deaths Due to Covid in US**

# %%
df_death = df_US.filter(['new_deaths_smoothed_per_million','date'], axis=1)

plt.figure(figsize=(20,4))
plt.plot(df_death['date'], df_death['new_deaths_smoothed_per_million'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("DEATH DUE TO COVID", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('TREND OF DEATH DUE TO COVID IN US', fontsize=16)
# Out:
# Text(0.5, 0.98, 'TREND OF DEATH DUE TO COVID IN US')

# %% [markdown]
# **4.Let us observe trend of COVID TESTING taken in response to Deaths and New COVID CASES**

# %%
df_covid_test = df_US.filter(['new_tests_smoothed','date'], axis=1)

plt.figure(figsize=(20,4))
plt.plot(df_covid_test['date'], df_covid_test['new_tests_smoothed'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("COVID TESTING", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('TREND OF COVID TESTING IN RESPONSE OF NEW CASES', fontsize=16)
# Out:
# Text(0.5, 0.98, 'TREND OF COVID TESTING IN RESPONSE OF NEW CASES')

# %% [markdown]
# **5. Let us understand the virulancy of Virus, What is the trend of Virus being spread from one individual to others, When was it more virulant in our time series data**

# %%
df_virus_r_rate = df_US.filter(['reproduction_rate','date'], axis=1)

plt.figure(figsize=(20,4))
plt.plot(df_virus_r_rate['date'], df_virus_r_rate['reproduction_rate'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("Virus R Rate", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('TREND OF HOW VIRULANT VIRUS IS?', fontsize=16)
# Out:
# Text(0.5, 0.98, 'TREND OF HOW VIRULANT VIRUS IS?')

# %% [markdown]
# **Once we have observed trend of COVID Cases,Deaths and Observed the response of people of US getting tested. We have certain questions "If someone is infected by Covid how likely will they die**
#
# **Let us answer these questions using various ration**

# %% [markdown]
# **CFR**
# The Case Fatality Rate = the number of confirmed deaths divided by the number of confirmed cases.
# It measures the severity of a particular disease by defining the total number of deaths as a proportion of reported cases of a specific disease at a specific time.

# %%
df_CFR = df_US.filter(['new_cases_smoothed_per_million','new_deaths_smoothed_per_million','date'], axis=1)
df_CFR['CFR'] = ((df_CFR['new_deaths_smoothed_per_million']/df_CFR['new_cases_smoothed_per_million'])*100)

# %%
df_CFR = df_CFR.dropna()
df_CFR
# Out:
#         new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 154832                           0.002                            0.000
# 154833                           0.002                            0.000
# 154834                           0.002                            0.000
# 154835                           0.003                            0.000
# 154836                           0.003                            0.000
# ...                                ...                              ...
# 155584                         323.485                            6.632
# 155585                         314.132                            6.551
# 155586                         299.165                            6.520
# 155587                         259.515                            5.602
# 155588                         252.978                            5.470
#
#              date       CFR
# 154832 2020-01-28  0.000000
# 154833 2020-01-29  0.000000
# 154834 2020-01-30  0.000000
# 154835 2020-01-31  0.000000
# 154836 2020-02-01  0.000000
# ...           ...       ...
# 155584 2022-02-18  2.050172
# 155585 2022-02-19  2.085429
# 155586 2022-02-20  2.179399
# 155587 2022-02-21  2.158642
# 155588 2022-02-22  2.162243
#
# [752 rows x 4 columns]

# %%
plt.figure(figsize=(20,4))
plt.plot(df_CFR['date'], df_CFR['CFR'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("CASE FATALITY RATE", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('COVID CASE FATALITY RATE', fontsize=16)
# Out:
# Text(0.5, 0.98, 'COVID CASE FATALITY RATE')

# %% [markdown]
# Let us ask more good questions
#
# If someone is infected with COVID-19,how likely is that person to die?
# Point to note and understand about data,
# If data had no lag, which means all the cases were reported on time and all the people infected with Covid are tested then the CFR would have addressed this answer, but in real world data not all cases are reported, we have misreported data and not all who got infected with covid were tested.

# %% [markdown]
# Also note the value of CFR changes and it depends on multiple factors. The calculation of probablity that individual is infected with Covid and will die not only depends on Covid Positive and confirmed cases but also on individual factors like:
# 1. Person age
# 2. Comorbidity
# 3. Age
# 4. Sex
#
# Below is the CFR we found for different diseases in past.

# %% [markdown]
# ![Screen Shot 2022-03-02 at 7.10.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# **Let us calculate CMR - Crude Mortality Rate**
#
# CMR is defined as  Number of deaths over a given period divided by the person-years lived by the population over that period. It is expressed as number of deaths per 1,000 population.

# %%
#Crude Mortality Rate / Crude Death rate 
df_cmr = df_US.filter(['new_deaths_smoothed','population','date'], axis=1)
df_cmr = df_cmr.dropna()
df_cmr['CMR'] = (df_cmr['new_deaths_smoothed']/df_cmr['population'])*100


#Crude Mortality Rate Plot
plt.figure(figsize=(20,4))
plt.plot(df_cmr['date'], df_cmr['CMR'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("CASE MORATALITY RATE", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('COVID CASE MORTALITY RATE', fontsize=16)
# Out:
# Text(0.5, 0.98, 'COVID CASE MORTALITY RATE')

# %% [markdown]
# **IFR - Risk of Death per infection**
# Infection Fatality Rate
# if someone is infected with the disease how likely is it that they will die from it?
# #IFR = (number of deaths/total number of cases ) * 100

# %%
#@title Default title text
df_ifr = df_US.filter(['new_deaths_smoothed','new_cases_smoothed','date'], axis=1)
df_ifr = df_ifr.dropna()
df_ifr['IFR'] = (df_ifr['new_deaths_smoothed']/df_ifr['new_cases_smoothed'])*100


#Infection Fatality Rate Plot
plt.figure(figsize=(20,4))
plt.plot(df_ifr['date'], df_ifr['IFR'])
plt.xlabel("DATE", fontsize=14)
plt.ylabel("INFECTION FATALITY RATE", fontsize=14)
#plt.yticks(range(0, 1700000, 200000))
plt.xlabel("DATE",fontsize=14)
plt.suptitle('COVID INFECTION FATALITY RATE', fontsize=16)
# Out:
# Text(0.5, 0.98, 'COVID INFECTION FATALITY RATE')
